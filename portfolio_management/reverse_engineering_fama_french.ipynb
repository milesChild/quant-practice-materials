# %% [markdown]
# # Reverse-Engineering the Fama-French Five Factor Model Using Principal Component Analysis
#
# Miles Child
# November 18, 2023
#
# In this notebook, I will isolate the factor loadings for five of the Fama-French factors on the S&P 100 and attempt to reconstruct them using PCA. I have run Fama-French in the past and have been attracted to the qualitative explainability of Fama-French and detracted by the concept that five intuitions can explain the majority of asset return variance. With PCA, I have been attracted to the abstract methodology of explaining asset return variance but detracted from the inability to rationalize why these latent variables exist and why they should continue to exist.
#
# Principal components will be "matched" with the Fama-French factors on the basis of statistical correlation between their factor loadings.
#
# Unmatchable components will be assumed to be either (1) one of the other fama-french factors, (2) some other known but not fama-french factor, or **(3) idiosyncratic factors**.
#
# Hopefully I am successful in this reverse-engineering so that a middle-ground can be identified (this seems like something that's been done a million times before but I'm going to do it anyway for better understanding of both factor isolation methods).
#
# **Note:**
#
# See fama_french.ipynb and pca.ipynb in lib/ for independent examples of the two.
#
# ____________________

# %% [markdown]
# #### Step 1: Load Data

# %%
# imports

import pandas as pd
import numpy as np
import yfinance as yf
from scipy.stats import uniform
from scipy.optimize import minimize
from numpy.linalg import inv
import pandas_datareader.data as web
from numpy.random import random, uniform, dirichlet, choice

# %%
# Get the list of constituents in the S&P 100 index
sp100_constituents = pd.read_html("https://en.wikipedia.org/wiki/S%26P_100")[2]
tickers = sp100_constituents['Symbol'].tolist()

# Define the start and end dates for the historical data
start_date = "2021-01-01"
end_date = "2023-06-31"

# Create a dictionary to store the historical data for each stock
stock_data_dict = {}

# Fetch historical data for each stock
for ticker in tickers:
    try:
        # get daily data
        stock_data = yf.download(ticker, start_date, end_date)
        stock_data_dict[ticker] = stock_data
    except Exception as e:
        print(f"Error fetching data for {ticker}: {e}")

sample_ticker = tickers[0]
print(stock_data_dict[sample_ticker].head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ABBV: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ABT: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ACN: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ADBE: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AIG: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMD: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMGN: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMT: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMZN: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AVGO: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AXP: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BA: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAC: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BK: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BKNG: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BLK: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BMY: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - C: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CAT: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CHTR: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CL: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CMCSA: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - COF: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - COP: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - COST: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CRM: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CSCO: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CVS: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CVX: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DE: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DHR: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DIS: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DOW: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DUK: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EMR: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EXC: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - F: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - FDX: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GD: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GE: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GILD: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GM: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GOOG: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GOOGL: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GS: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - HD: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - HON: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - IBM: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - INTC: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - JNJ: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - JPM: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - KHC: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - KO: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - LIN: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - LLY: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - LMT: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - LOW: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MA: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MCD: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MDLZ: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MDT: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MET: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - META: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MMM: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MO: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MRK: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MS: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MSFT: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - NEE: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - NFLX: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - NKE: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - NVDA: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ORCL: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - PEP: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - PFE: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - PG: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - PM: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - PYPL: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - QCOM: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - RTX: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - SBUX: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - SCHW: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - SO: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - SPG: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - T: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - TGT: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - TMO: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - TMUS: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - TSLA: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - TXN: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - UNH: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - UNP: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - UPS: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - USB: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - V: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - VZ: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WFC: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WMT: ValueError('day is out of range for month')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - XOM: ValueError('day is out of range for month')
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# #### Step 2: Fama French Factors
