# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import coint
from statsmodels.api import OLS
import yfinance as yf

# %%
usa = pd.read_excel('excel_data/USA.xlsx')
usa.head()
# Out:
#         Date  Close   NAV
# 0 2023-01-20   5.98  6.08
# 1 2023-01-19   6.00  5.95
# 2 2023-01-18   6.24  6.16
# 3 2023-01-17   6.38  6.25
# 4 2023-01-13   6.22  6.26

# %%
# Plot a time series of the close and nav over time
usa[['Close', 'NAV']].plot(figsize=(10, 5))
plt.show()
